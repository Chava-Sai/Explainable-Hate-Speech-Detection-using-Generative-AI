# %% [markdown]
# # Web Scraping

# %% [markdown]
# ## Scrapping and Storing in file

# %%
# !pip install sentence_transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 3.2 MB/s eta 0:00:00

# %%
from bs4 import BeautifulSoup
import re
import pandas as pd

def extract_title_and_content(html_file):
    with open(html_file, 'r', encoding='utf-8') as file:
        html_content = file.read()

    soup = BeautifulSoup(html_content, 'html.parser')

    # Extract title
    title = soup.title.string if soup.title else None

    # Remove script and style tags
    for script in soup(["script", "style"]):
        script.extract()

    # Exclude elements by their attributes or specific content
    excluded_tags = ['script', 'style', 'meta', 'noscript', 'footer', 'nav', 'aside']
    for tag in soup(excluded_tags):
        tag.extract()

    # Extract text content
    content = soup.get_text().strip()

    return title, content

if __name__ == "__main__":
    html_file = 'Opinion_ Yes, Hinduism Is Indeed Under Threat.html'
    title, content = extract_title_and_content(html_file)

    # Load existing data or create new DataFrame
    try:
        existing_data = pd.read_excel('VectorDB_Data.xlsx')
    except FileNotFoundError:
        existing_data = pd.DataFrame(columns=['Data'])

    # Append new data to existing DataFrame or create new DataFrame
    new_data = {'Data': content}
    existing_data = existing_data.append(new_data, ignore_index=True)

    # Save the data in an Excel file
    existing_data.to_excel('VectorDB_Data.xlsx', index=False)

    print("Data saved")
# Out:
# <ipython-input-1-ec2fb4835a6c>:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   existing_data = existing_data.append(new_data, ignore_index=True)
# Data saved

# %%
import pandas as pd

df = pd.read_excel("VectorDB_Data.xlsx")
df.head()
# Out:
#                                                 Data
# 0  Opinion: Yes, Hinduism Is Indeed Under Threat ...
# 1  Pathaan: Why Shah Rukh Khan's comeback film is...

# %%
import pandas as pd

# Load the dataset
try:
    dataset = pd.read_excel('VectorDB_Data.xlsx')
except FileNotFoundError:
    print("Dataset file not found.")
    exit()

# Add index to the dataset
dataset.insert(0, 'Index', range(1, len(dataset) + 1))

# Save the dataset with index
dataset.to_excel('VectorDB_with_index.xlsx', index=False)

print("Index added and dataset saved as 'VectorDB_with_index.xlsx'")
# Out:
# Index added and dataset saved as 'VectorDB_with_index.xlsx'
